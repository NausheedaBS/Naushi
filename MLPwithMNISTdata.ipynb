# %%
# Imports
import tensorflow
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Configuration options
feature_vector_length = 784
num_classes = 10

# Load the data
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# Reshape the data - MLPs do not understand such things as '2D'.
# Reshape to 28 x 28 pixels = 784 features
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, num_classes)
Y_test = to_categorical(Y_test, num_classes)

# %%
# Set the input shape
input_shape = (feature_vector_length,)
print(f'Feature shape: {input_shape}')

# Create the model
model = Sequential()
model.add(Dense(350, input_shape=input_shape, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Configure the model and start training
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=10, batch_size=250, verbose=1, validation_split=0.2)

# Test the model after training
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
# Out:
# Feature shape: (784,)
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 4s 84us/sample - loss: 0.3822 - accuracy: 0.8914 - val_loss: 0.1706 - val_accuracy: 0.9503
# Epoch 2/10
# 48000/48000 [==============================] - 2s 51us/sample - loss: 0.1444 - accuracy: 0.9574 - val_loss: 0.1250 - val_accuracy: 0.9630
# Epoch 3/10
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.0977 - accuracy: 0.9712 - val_loss: 0.1015 - val_accuracy: 0.9692
# Epoch 4/10
# 48000/48000 [==============================] - 2s 51us/sample - loss: 0.0711 - accuracy: 0.9791 - val_loss: 0.0949 - val_accuracy: 0.9700
# Epoch 5/10
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.0537 - accuracy: 0.9840 - val_loss: 0.0872 - val_accuracy: 0.9746
# Epoch 6/10
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.0395 - accuracy: 0.9881 - val_loss: 0.0889 - val_accuracy: 0.9728
# Epoch 7/10
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.0300 - accuracy: 0.9918 - val_loss: 0.0848 - val_accuracy: 0.9744
# Epoch 8/10
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.0237 - accuracy: 0.9938 - val_loss: 0.0929 - val_accuracy: 0.9738
# Epoch 9/10
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.0180 - accuracy: 0.9954 - val_loss: 0.0799 - val_accuracy: 0.9765
# Epoch 10/10
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.0843 - val_accuracy: 0.9754
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test results - Loss: 0.0738754422209342 - Accuracy: 0.9764999747276306%
